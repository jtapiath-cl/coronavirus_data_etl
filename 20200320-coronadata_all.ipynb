# %%
import os
import pandas as pd
import numpy as np

output_file = "data_final.csv"

# %%
cases_data = pd.read_csv("data_to_plot.csv")
metadata_c = pd.read_excel("country_metadata.xlsx")

# %%
cases_data.head()
# Out:
#    index      country  conf  deth  recv          ts  days
# 0      0  Afghanistan     1     0     0  2020-02-24     1
# 1      1  Afghanistan     1     0     0  2020-02-25     2
# 2      2  Afghanistan     1     0     0  2020-02-26     3
# 3      3  Afghanistan     1     0     0  2020-02-27     4
# 4      4  Afghanistan     1     0     0  2020-02-28     5

# %%
metadata_c.head()
# Out:
#         country_1       country_2       country_3 code continent  \
# 0     Afghanistan     Afghanistan     Afghanistan  AFG      Asia
# 1   Aland Islands   Aland Islands   Aland Islands  ALA    Europe
# 2         Albania         Albania         Albania  ALB    Europe
# 3         Algeria         Algeria         Algeria  DZA    Africa
# 4  American Samoa  American Samoa  American Samoa  ASM   Oceania
#
#         sub_region         pop         country
# 0    Southern Asia  37172386.0     Afghanistan
# 1  Northern Europe         NaN   Aland Islands
# 2  Southern Europe   2866376.0         Albania
# 3  Northern Africa  42228429.0         Algeria
# 4        Polynesia     55465.0  American Samoa

# %%
full_df = pd.merge(cases_data, metadata_c, how = "left", left_on = "country", right_on = "country")

# %%
full_df.head()
# Out:
#    index      country  conf  deth  recv          ts  days    country_1  \
# 0      0  Afghanistan     1     0     0  2020-02-24     1  Afghanistan
# 1      1  Afghanistan     1     0     0  2020-02-25     2  Afghanistan
# 2      2  Afghanistan     1     0     0  2020-02-26     3  Afghanistan
# 3      3  Afghanistan     1     0     0  2020-02-27     4  Afghanistan
# 4      4  Afghanistan     1     0     0  2020-02-28     5  Afghanistan
#
#      country_2    country_3 code continent     sub_region         pop
# 0  Afghanistan  Afghanistan  AFG      Asia  Southern Asia  37172386.0
# 1  Afghanistan  Afghanistan  AFG      Asia  Southern Asia  37172386.0
# 2  Afghanistan  Afghanistan  AFG      Asia  Southern Asia  37172386.0
# 3  Afghanistan  Afghanistan  AFG      Asia  Southern Asia  37172386.0
# 4  Afghanistan  Afghanistan  AFG      Asia  Southern Asia  37172386.0

# %%
full_df.country_1.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Benin', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Bosnia and Herzegovina',
#        'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso',
#        'Cambodia', 'Cameroon', 'Canada', 'Central African Republic',
#        'Chad', 'Chile', 'China', 'Colombia', 'Congo',
#        'Congo (Democratic Republic of the)', 'Costa Rica',
#        "C�te d'Ivoire", 'Croatia', nan, 'Cuba', 'Cyprus',
#        'Czech Republic', 'Denmark', 'Djibouti', 'Dominican Republic',
#        'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Estonia',
#        'Swaziland', 'Ethiopia', 'Fiji', 'Finland', 'France', 'Gabon',
#        'Gambia', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Guatemala',
# ...

# %%
full_df[full_df.country.isna()]
# Out:
# Empty DataFrame
# Columns: [index, country, conf, deth, recv, ts, days, country_1, country_2, country_3, code, continent, sub_region, pop]
# Index: []

# %%
full_df[full_df.country.isna()][["country", "country_1", "country_2", "country_3"]]
# Out:
# Empty DataFrame
# Columns: [country, country_1, country_2, country_3]
# Index: []

# %%
full_df.head()
# Out:
#    index      country  conf  deth  recv          ts  days    country_1  \
# 0      0  Afghanistan     1     0     0  2020-02-24     1  Afghanistan
# 1      1  Afghanistan     1     0     0  2020-02-25     2  Afghanistan
# 2      2  Afghanistan     1     0     0  2020-02-26     3  Afghanistan
# 3      3  Afghanistan     1     0     0  2020-02-27     4  Afghanistan
# 4      4  Afghanistan     1     0     0  2020-02-28     5  Afghanistan
#
#      country_2    country_3 code continent     sub_region         pop
# 0  Afghanistan  Afghanistan  AFG      Asia  Southern Asia  37172386.0
# 1  Afghanistan  Afghanistan  AFG      Asia  Southern Asia  37172386.0
# 2  Afghanistan  Afghanistan  AFG      Asia  Southern Asia  37172386.0
# 3  Afghanistan  Afghanistan  AFG      Asia  Southern Asia  37172386.0
# 4  Afghanistan  Afghanistan  AFG      Asia  Southern Asia  37172386.0

# %%
full_df.drop(inplace = True, columns = ["country_1", "country_2", "country_3"])

# %%
if os.path.exists(output_file):
    os.remove(output_file)
else:
    pass

# %%
full_df.to_csv(output_file, index = False)
